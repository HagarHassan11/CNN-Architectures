# %% [markdown]
# <a href="https://colab.research.google.com/github/HagarHassan11/CNN-Architectures/blob/main/ResNet_50_from_Scratch_MNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.datasets import mnist
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras import layers, models
import tensorflow as tf
from tensorflow.keras.datasets import mnist, cifar10
from tensorflow.keras.utils import to_categorical

# %%
def identity_block(X, f, filters, stage, block):


    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value. we'll need this later to add back to the main path.
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(1, 1), padding='valid',
               name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    # Second component of main path
    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same',
               name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    # Third component of main path
    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid',
               name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def convolutional_block(X, f, filters, stage, block, s=2):

    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'

    # Retrieve Filters
    F1, F2, F3 = filters

    # Save the input value
    X_shortcut = X

    # First component of main path
    X = Conv2D(filters=F1, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '2a', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F2, kernel_size=(f, f), strides=(1, 1), padding='same', name=conv_name_base + '2b', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters=F3, kernel_size=(1, 1), strides=(1, 1), padding='valid', name=conv_name_base + '2c', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name=bn_name_base + '2c')(X)

    X_shortcut = Conv2D(filters=F3, kernel_size=(1, 1), strides=(s, s), padding='valid', name=conv_name_base + '1', kernel_initializer=glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis=3, name=bn_name_base + '1')(X_shortcut)

    # Final step: Add shortcut value to main path, and pass it through a RELU activation (≈2 lines)
    X = Add()([X, X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
def ResNet50(input_shape, outputClasses):

    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)

    # Stage 1
    X = Conv2D(64, (7, 7), strides=(2, 2), name='conv1', kernel_initializer=glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3, name='bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f=3, filters=[64, 64, 256], stage=2, block='a', s=1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    # Stage 3
    X = convolutional_block(X, f=3, filters=[128, 128, 512], stage=3, block='a', s=2)
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [128, 128, 512], stage=3, block='d')

    # Stage 4
    X = convolutional_block(X, f=3, filters=[256, 256, 1024], stage=4, block='a', s=2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    # Stage 5
    X = convolutional_block(X, f=3, filters=[512, 512, 2048], stage=5, block='a', s=2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    # AVGPOOL
    X = AveragePooling2D(pool_size=(2, 2), padding='same')(X)

    # output layer
    X = Flatten()(X)
    X = Dense(outputClasses, activation='softmax', name='fc' + str(outputClasses),
              kernel_initializer=glorot_uniform(seed=0))(X)

    # Create model
    model = Model(inputs=X_input, outputs=X, name='ResNet50')

    return model

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %%
x_train = x_train.reshape(-1, 28, 28, 1) / 255.0
x_test = x_test.reshape(-1, 28, 28, 1) / 255.0
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
model = ResNet50(input_shape=(28, 28, 1), num_classes=10)

# %%
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, batch_size=64, epochs=10, validation_data=(x_test, y_test))
# Out:
# Epoch 1/10
# 938/938 [==============================] - 811s 811ms/step - loss: 0.4259 - accuracy: 0.8940 - val_loss: 0.3417 - val_accuracy: 0.8936
# Epoch 2/10
# 938/938 [==============================] - 755s 805ms/step - loss: 0.1746 - accuracy: 0.9569 - val_loss: 0.2212 - val_accuracy: 0.9303
# Epoch 3/10
# 938/938 [==============================] - 751s 801ms/step - loss: 0.1105 - accuracy: 0.9727 - val_loss: 0.0547 - val_accuracy: 0.9823
# Epoch 4/10
# 938/938 [==============================] - 737s 786ms/step - loss: 0.3753 - accuracy: 0.9121 - val_loss: 0.4931 - val_accuracy: 0.8628
# Epoch 5/10
# 938/938 [==============================] - 756s 806ms/step - loss: 0.1038 - accuracy: 0.9691 - val_loss: 0.0692 - val_accuracy: 0.9783
# Epoch 6/10
# 938/938 [==============================] - 756s 806ms/step - loss: 0.1552 - accuracy: 0.9636 - val_loss: 0.0581 - val_accuracy: 0.9817
# Epoch 7/10
# 938/938 [==============================] - 738s 786ms/step - loss: 0.2189 - accuracy: 0.9365 - val_loss: 0.1254 - val_accuracy: 0.9606
# Epoch 8/10
# 938/938 [==============================] - 756s 806ms/step - loss: 0.0897 - accuracy: 0.9729 - val_loss: 0.0531 - val_accuracy: 0.9832
# Epoch 9/10
# 938/938 [==============================] - 756s 806ms/step - loss: 0.1232 - accuracy: 0.9688 - val_loss: 229.6905 - val_accuracy: 0.3614
# Epoch 10/10
# 938/938 [==============================] - 756s 806ms/step - loss: 0.1091 - accuracy: 0.9686 - val_loss: 0.0493 - val_accuracy: 0.9830

# %%
model.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d_186 (Conv2D)         (None, 14, 14, 64)           3200      ['input_4[0][0]']
#
#  batch_normalization_186 (B  (None, 14, 14, 64)           256       ['conv2d_186[0][0]']
#  atchNormalization)
#
#  activation_228 (Activation  (None, 14, 14, 64)           0         ['batch_normalization_186[0][0
#  )                                                                  ]']
#
#  max_pooling2d_3 (MaxPoolin  (None, 7, 7, 64)             0         ['activation_228[0][0]']
#  g2D)
#
#  conv2d_187 (Conv2D)         (None, 7, 7, 64)             36928     ['max_pooling2d_3[0][0]']
#
#  batch_normalization_187 (B  (None, 7, 7, 64)             256       ['conv2d_187[0][0]']
#  atchNormalization)
#
#  activation_229 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_187[0][0
#  )                                                                  ]']
#
#  conv2d_188 (Conv2D)         (None, 7, 7, 64)             36928     ['activation_229[0][0]']
#
#  batch_normalization_188 (B  (None, 7, 7, 64)             256       ['conv2d_188[0][0]']
#  atchNormalization)
#
#  activation_230 (Activation  (None, 7, 7, 64)             0         ['batch_normalization_188[0][0
#  )                                                                  ]']
#
#  conv2d_189 (Conv2D)         (None, 7, 7, 256)            147712    ['activation_230[0][0]']
#
#  batch_normalization_189 (B  (None, 7, 7, 256)            1024      ['conv2d_189[0][0]']
#  atchNormalization)
#
#  activation_231 (Activation  (None, 7, 7, 256)            0         ['batch_normalization_189[0][0
#  )                                                                  ]']
#
#  conv2d_191 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_231[0][0]']
#
#  batch_normalization_191 (B  (None, 4, 4, 256)            1024      ['conv2d_191[0][0]']
#  atchNormalization)
#
#  activation_232 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_191[0][0
#  )                                                                  ]']
#
#  conv2d_192 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_232[0][0]']
#
#  batch_normalization_192 (B  (None, 4, 4, 256)            1024      ['conv2d_192[0][0]']
#  atchNormalization)
#
#  activation_233 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_192[0][0
#  )                                                                  ]']
#
#  conv2d_193 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_233[0][0]']
#
#  conv2d_190 (Conv2D)         (None, 4, 4, 256)            65792     ['activation_231[0][0]']
#
#  batch_normalization_193 (B  (None, 4, 4, 256)            1024      ['conv2d_193[0][0]']
#  atchNormalization)
#
#  batch_normalization_190 (B  (None, 4, 4, 256)            1024      ['conv2d_190[0][0]']
#  atchNormalization)
#
#  activation_234 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_193[0][0
#  )                                                                  ]']
#
#  add_54 (Add)                (None, 4, 4, 256)            0         ['batch_normalization_190[0][0
#                                                                     ]',
#                                                                      'activation_234[0][0]']
#
#  activation_235 (Activation  (None, 4, 4, 256)            0         ['add_54[0][0]']
#  )
#
#  conv2d_194 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_235[0][0]']
#
#  batch_normalization_194 (B  (None, 4, 4, 256)            1024      ['conv2d_194[0][0]']
#  atchNormalization)
#
#  activation_236 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_194[0][0
#  )                                                                  ]']
#
#  conv2d_195 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_236[0][0]']
#
#  batch_normalization_195 (B  (None, 4, 4, 256)            1024      ['conv2d_195[0][0]']
#  atchNormalization)
#
#  activation_237 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_195[0][0
#  )                                                                  ]']
#
#  conv2d_196 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_237[0][0]']
#
#  batch_normalization_196 (B  (None, 4, 4, 256)            1024      ['conv2d_196[0][0]']
#  atchNormalization)
#
#  activation_238 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_196[0][0
#  )                                                                  ]']
#
#  add_55 (Add)                (None, 4, 4, 256)            0         ['activation_235[0][0]',
#                                                                      'activation_238[0][0]']
#
#  activation_239 (Activation  (None, 4, 4, 256)            0         ['add_55[0][0]']
#  )
#
#  conv2d_197 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_239[0][0]']
#
#  batch_normalization_197 (B  (None, 4, 4, 256)            1024      ['conv2d_197[0][0]']
#  atchNormalization)
#
#  activation_240 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_197[0][0
#  )                                                                  ]']
#
#  conv2d_198 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_240[0][0]']
#
#  batch_normalization_198 (B  (None, 4, 4, 256)            1024      ['conv2d_198[0][0]']
#  atchNormalization)
#
#  activation_241 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_198[0][0
#  )                                                                  ]']
#
#  conv2d_199 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_241[0][0]']
#
#  batch_normalization_199 (B  (None, 4, 4, 256)            1024      ['conv2d_199[0][0]']
#  atchNormalization)
#
#  activation_242 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_199[0][0
#  )                                                                  ]']
#
#  add_56 (Add)                (None, 4, 4, 256)            0         ['activation_239[0][0]',
#                                                                      'activation_242[0][0]']
#
#  activation_243 (Activation  (None, 4, 4, 256)            0         ['add_56[0][0]']
#  )
#
#  conv2d_200 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_243[0][0]']
#
#  batch_normalization_200 (B  (None, 4, 4, 256)            1024      ['conv2d_200[0][0]']
#  atchNormalization)
#
#  activation_244 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_200[0][0
#  )                                                                  ]']
#
#  conv2d_201 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_244[0][0]']
#
#  batch_normalization_201 (B  (None, 4, 4, 256)            1024      ['conv2d_201[0][0]']
#  atchNormalization)
#
#  activation_245 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_201[0][0
#  )                                                                  ]']
#
#  conv2d_202 (Conv2D)         (None, 4, 4, 256)            590080    ['activation_245[0][0]']
#
#  batch_normalization_202 (B  (None, 4, 4, 256)            1024      ['conv2d_202[0][0]']
#  atchNormalization)
#
#  activation_246 (Activation  (None, 4, 4, 256)            0         ['batch_normalization_202[0][0
#  )                                                                  ]']
#
#  add_57 (Add)                (None, 4, 4, 256)            0         ['activation_243[0][0]',
#                                                                      'activation_246[0][0]']
#
#  activation_247 (Activation  (None, 4, 4, 256)            0         ['add_57[0][0]']
#  )
#
#  conv2d_204 (Conv2D)         (None, 2, 2, 512)            1180160   ['activation_247[0][0]']
#
#  batch_normalization_204 (B  (None, 2, 2, 512)            2048      ['conv2d_204[0][0]']
#  atchNormalization)
#
#  activation_248 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_204[0][0
#  )                                                                  ]']
#
#  conv2d_205 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_248[0][0]']
#
#  batch_normalization_205 (B  (None, 2, 2, 512)            2048      ['conv2d_205[0][0]']
#  atchNormalization)
#
#  activation_249 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_205[0][0
#  )                                                                  ]']
#
#  conv2d_206 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_249[0][0]']
#
#  conv2d_203 (Conv2D)         (None, 2, 2, 512)            131584    ['activation_247[0][0]']
#
#  batch_normalization_206 (B  (None, 2, 2, 512)            2048      ['conv2d_206[0][0]']
#  atchNormalization)
#
#  batch_normalization_203 (B  (None, 2, 2, 512)            2048      ['conv2d_203[0][0]']
#  atchNormalization)
#
#  activation_250 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_206[0][0
#  )                                                                  ]']
#
#  add_58 (Add)                (None, 2, 2, 512)            0         ['batch_normalization_203[0][0
#                                                                     ]',
#                                                                      'activation_250[0][0]']
#
#  activation_251 (Activation  (None, 2, 2, 512)            0         ['add_58[0][0]']
#  )
#
#  conv2d_207 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_251[0][0]']
#
#  batch_normalization_207 (B  (None, 2, 2, 512)            2048      ['conv2d_207[0][0]']
#  atchNormalization)
#
#  activation_252 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_207[0][0
#  )                                                                  ]']
#
#  conv2d_208 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_252[0][0]']
#
#  batch_normalization_208 (B  (None, 2, 2, 512)            2048      ['conv2d_208[0][0]']
#  atchNormalization)
#
#  activation_253 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_208[0][0
#  )                                                                  ]']
#
#  conv2d_209 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_253[0][0]']
#
#  batch_normalization_209 (B  (None, 2, 2, 512)            2048      ['conv2d_209[0][0]']
#  atchNormalization)
#
#  activation_254 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_209[0][0
#  )                                                                  ]']
#
#  add_59 (Add)                (None, 2, 2, 512)            0         ['activation_251[0][0]',
#                                                                      'activation_254[0][0]']
#
#  activation_255 (Activation  (None, 2, 2, 512)            0         ['add_59[0][0]']
#  )
#
#  conv2d_210 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_255[0][0]']
#
#  batch_normalization_210 (B  (None, 2, 2, 512)            2048      ['conv2d_210[0][0]']
#  atchNormalization)
#
#  activation_256 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_210[0][0
#  )                                                                  ]']
#
#  conv2d_211 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_256[0][0]']
#
#  batch_normalization_211 (B  (None, 2, 2, 512)            2048      ['conv2d_211[0][0]']
#  atchNormalization)
#
#  activation_257 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_211[0][0
#  )                                                                  ]']
#
#  conv2d_212 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_257[0][0]']
#
#  batch_normalization_212 (B  (None, 2, 2, 512)            2048      ['conv2d_212[0][0]']
#  atchNormalization)
#
#  activation_258 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_212[0][0
#  )                                                                  ]']
#
#  add_60 (Add)                (None, 2, 2, 512)            0         ['activation_255[0][0]',
#                                                                      'activation_258[0][0]']
#
#  activation_259 (Activation  (None, 2, 2, 512)            0         ['add_60[0][0]']
#  )
#
#  conv2d_213 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_259[0][0]']
#
#  batch_normalization_213 (B  (None, 2, 2, 512)            2048      ['conv2d_213[0][0]']
#  atchNormalization)
#
#  activation_260 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_213[0][0
#  )                                                                  ]']
#
#  conv2d_214 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_260[0][0]']
#
#  batch_normalization_214 (B  (None, 2, 2, 512)            2048      ['conv2d_214[0][0]']
#  atchNormalization)
#
#  activation_261 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_214[0][0
#  )                                                                  ]']
#
#  conv2d_215 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_261[0][0]']
#
#  batch_normalization_215 (B  (None, 2, 2, 512)            2048      ['conv2d_215[0][0]']
#  atchNormalization)
#
#  activation_262 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_215[0][0
#  )                                                                  ]']
#
#  add_61 (Add)                (None, 2, 2, 512)            0         ['activation_259[0][0]',
#                                                                      'activation_262[0][0]']
#
#  activation_263 (Activation  (None, 2, 2, 512)            0         ['add_61[0][0]']
#  )
#
#  conv2d_216 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_263[0][0]']
#
#  batch_normalization_216 (B  (None, 2, 2, 512)            2048      ['conv2d_216[0][0]']
#  atchNormalization)
#
#  activation_264 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_216[0][0
#  )                                                                  ]']
#
#  conv2d_217 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_264[0][0]']
#
#  batch_normalization_217 (B  (None, 2, 2, 512)            2048      ['conv2d_217[0][0]']
#  atchNormalization)
#
#  activation_265 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_217[0][0
#  )                                                                  ]']
#
#  conv2d_218 (Conv2D)         (None, 2, 2, 512)            2359808   ['activation_265[0][0]']
#
#  batch_normalization_218 (B  (None, 2, 2, 512)            2048      ['conv2d_218[0][0]']
#  atchNormalization)
#
#  activation_266 (Activation  (None, 2, 2, 512)            0         ['batch_normalization_218[0][0
#  )                                                                  ]']
#
#  add_62 (Add)                (None, 2, 2, 512)            0         ['activation_263[0][0]',
#                                                                      'activation_266[0][0]']
#
#  activation_267 (Activation  (None, 2, 2, 512)            0         ['add_62[0][0]']
#  )
#
#  conv2d_220 (Conv2D)         (None, 1, 1, 1024)           4719616   ['activation_267[0][0]']
#
#  batch_normalization_220 (B  (None, 1, 1, 1024)           4096      ['conv2d_220[0][0]']
#  atchNormalization)
#
#  activation_268 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_220[0][0
#  )                                                                  ]']
#
#  conv2d_221 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_268[0][0]']
#
#  batch_normalization_221 (B  (None, 1, 1, 1024)           4096      ['conv2d_221[0][0]']
#  atchNormalization)
#
#  activation_269 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_221[0][0
#  )                                                                  ]']
#
#  conv2d_222 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_269[0][0]']
#
#  conv2d_219 (Conv2D)         (None, 1, 1, 1024)           525312    ['activation_267[0][0]']
#
#  batch_normalization_222 (B  (None, 1, 1, 1024)           4096      ['conv2d_222[0][0]']
#  atchNormalization)
#
#  batch_normalization_219 (B  (None, 1, 1, 1024)           4096      ['conv2d_219[0][0]']
#  atchNormalization)
#
#  activation_270 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_222[0][0
#  )                                                                  ]']
#
#  add_63 (Add)                (None, 1, 1, 1024)           0         ['batch_normalization_219[0][0
#                                                                     ]',
#                                                                      'activation_270[0][0]']
#
#  activation_271 (Activation  (None, 1, 1, 1024)           0         ['add_63[0][0]']
#  )
#
#  conv2d_223 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_271[0][0]']
#
#  batch_normalization_223 (B  (None, 1, 1, 1024)           4096      ['conv2d_223[0][0]']
#  atchNormalization)
#
#  activation_272 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_223[0][0
#  )                                                                  ]']
#
#  conv2d_224 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_272[0][0]']
#
#  batch_normalization_224 (B  (None, 1, 1, 1024)           4096      ['conv2d_224[0][0]']
#  atchNormalization)
#
#  activation_273 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_224[0][0
#  )                                                                  ]']
#
#  conv2d_225 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_273[0][0]']
#
#  batch_normalization_225 (B  (None, 1, 1, 1024)           4096      ['conv2d_225[0][0]']
#  atchNormalization)
#
#  activation_274 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_225[0][0
#  )                                                                  ]']
#
#  add_64 (Add)                (None, 1, 1, 1024)           0         ['activation_271[0][0]',
#                                                                      'activation_274[0][0]']
#
#  activation_275 (Activation  (None, 1, 1, 1024)           0         ['add_64[0][0]']
#  )
#
#  conv2d_226 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_275[0][0]']
#
#  batch_normalization_226 (B  (None, 1, 1, 1024)           4096      ['conv2d_226[0][0]']
#  atchNormalization)
#
#  activation_276 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_226[0][0
#  )                                                                  ]']
#
#  conv2d_227 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_276[0][0]']
#
#  batch_normalization_227 (B  (None, 1, 1, 1024)           4096      ['conv2d_227[0][0]']
#  atchNormalization)
#
#  activation_277 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_227[0][0
#  )                                                                  ]']
#
#  conv2d_228 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_277[0][0]']
#
#  batch_normalization_228 (B  (None, 1, 1, 1024)           4096      ['conv2d_228[0][0]']
#  atchNormalization)
#
#  activation_278 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_228[0][0
#  )                                                                  ]']
#
#  add_65 (Add)                (None, 1, 1, 1024)           0         ['activation_275[0][0]',
#                                                                      'activation_278[0][0]']
#
#  activation_279 (Activation  (None, 1, 1, 1024)           0         ['add_65[0][0]']
#  )
#
#  conv2d_229 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_279[0][0]']
#
#  batch_normalization_229 (B  (None, 1, 1, 1024)           4096      ['conv2d_229[0][0]']
#  atchNormalization)
#
#  activation_280 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_229[0][0
#  )                                                                  ]']
#
#  conv2d_230 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_280[0][0]']
#
#  batch_normalization_230 (B  (None, 1, 1, 1024)           4096      ['conv2d_230[0][0]']
#  atchNormalization)
#
#  activation_281 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_230[0][0
#  )                                                                  ]']
#
#  conv2d_231 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_281[0][0]']
#
#  batch_normalization_231 (B  (None, 1, 1, 1024)           4096      ['conv2d_231[0][0]']
#  atchNormalization)
#
#  activation_282 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_231[0][0
#  )                                                                  ]']
#
#  add_66 (Add)                (None, 1, 1, 1024)           0         ['activation_279[0][0]',
#                                                                      'activation_282[0][0]']
#
#  activation_283 (Activation  (None, 1, 1, 1024)           0         ['add_66[0][0]']
#  )
#
#  conv2d_232 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_283[0][0]']
#
#  batch_normalization_232 (B  (None, 1, 1, 1024)           4096      ['conv2d_232[0][0]']
#  atchNormalization)
#
#  activation_284 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_232[0][0
#  )                                                                  ]']
#
#  conv2d_233 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_284[0][0]']
#
#  batch_normalization_233 (B  (None, 1, 1, 1024)           4096      ['conv2d_233[0][0]']
#  atchNormalization)
#
#  activation_285 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_233[0][0
#  )                                                                  ]']
#
#  conv2d_234 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_285[0][0]']
#
#  batch_normalization_234 (B  (None, 1, 1, 1024)           4096      ['conv2d_234[0][0]']
#  atchNormalization)
#
#  activation_286 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_234[0][0
#  )                                                                  ]']
#
#  add_67 (Add)                (None, 1, 1, 1024)           0         ['activation_283[0][0]',
#                                                                      'activation_286[0][0]']
#
#  activation_287 (Activation  (None, 1, 1, 1024)           0         ['add_67[0][0]']
#  )
#
#  conv2d_235 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_287[0][0]']
#
#  batch_normalization_235 (B  (None, 1, 1, 1024)           4096      ['conv2d_235[0][0]']
#  atchNormalization)
#
#  activation_288 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_235[0][0
#  )                                                                  ]']
#
#  conv2d_236 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_288[0][0]']
#
#  batch_normalization_236 (B  (None, 1, 1, 1024)           4096      ['conv2d_236[0][0]']
#  atchNormalization)
#
#  activation_289 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_236[0][0
#  )                                                                  ]']
#
#  conv2d_237 (Conv2D)         (None, 1, 1, 1024)           9438208   ['activation_289[0][0]']
#
#  batch_normalization_237 (B  (None, 1, 1, 1024)           4096      ['conv2d_237[0][0]']
#  atchNormalization)
#
#  activation_290 (Activation  (None, 1, 1, 1024)           0         ['batch_normalization_237[0][0
#  )                                                                  ]']
#
#  add_68 (Add)                (None, 1, 1, 1024)           0         ['activation_287[0][0]',
#                                                                      'activation_290[0][0]']
#
#  activation_291 (Activation  (None, 1, 1, 1024)           0         ['add_68[0][0]']
#  )
#
#  conv2d_239 (Conv2D)         (None, 1, 1, 2048)           1887641   ['activation_291[0][0]']
#                                                           6
#
#  batch_normalization_239 (B  (None, 1, 1, 2048)           8192      ['conv2d_239[0][0]']
#  atchNormalization)
#
#  activation_292 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_239[0][0
#  )                                                                  ]']
#
#  conv2d_240 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_292[0][0]']
#                                                           4
#
#  batch_normalization_240 (B  (None, 1, 1, 2048)           8192      ['conv2d_240[0][0]']
#  atchNormalization)
#
#  activation_293 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_240[0][0
#  )                                                                  ]']
#
#  conv2d_241 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_293[0][0]']
#                                                           4
#
#  conv2d_238 (Conv2D)         (None, 1, 1, 2048)           2099200   ['activation_291[0][0]']
#
#  batch_normalization_241 (B  (None, 1, 1, 2048)           8192      ['conv2d_241[0][0]']
#  atchNormalization)
#
#  batch_normalization_238 (B  (None, 1, 1, 2048)           8192      ['conv2d_238[0][0]']
#  atchNormalization)
#
#  activation_294 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_241[0][0
#  )                                                                  ]']
#
#  add_69 (Add)                (None, 1, 1, 2048)           0         ['batch_normalization_238[0][0
#                                                                     ]',
#                                                                      'activation_294[0][0]']
#
#  activation_295 (Activation  (None, 1, 1, 2048)           0         ['add_69[0][0]']
#  )
#
#  conv2d_242 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_295[0][0]']
#                                                           4
#
#  batch_normalization_242 (B  (None, 1, 1, 2048)           8192      ['conv2d_242[0][0]']
#  atchNormalization)
#
#  activation_296 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_242[0][0
#  )                                                                  ]']
#
#  conv2d_243 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_296[0][0]']
#                                                           4
#
#  batch_normalization_243 (B  (None, 1, 1, 2048)           8192      ['conv2d_243[0][0]']
#  atchNormalization)
#
#  activation_297 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_243[0][0
#  )                                                                  ]']
#
#  conv2d_244 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_297[0][0]']
#                                                           4
#
#  batch_normalization_244 (B  (None, 1, 1, 2048)           8192      ['conv2d_244[0][0]']
#  atchNormalization)
#
#  activation_298 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_244[0][0
#  )                                                                  ]']
#
#  add_70 (Add)                (None, 1, 1, 2048)           0         ['activation_295[0][0]',
#                                                                      'activation_298[0][0]']
#
#  activation_299 (Activation  (None, 1, 1, 2048)           0         ['add_70[0][0]']
#  )
#
#  conv2d_245 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_299[0][0]']
#                                                           4
#
#  batch_normalization_245 (B  (None, 1, 1, 2048)           8192      ['conv2d_245[0][0]']
#  atchNormalization)
#
#  activation_300 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_245[0][0
#  )                                                                  ]']
#
#  conv2d_246 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_300[0][0]']
#                                                           4
#
#  batch_normalization_246 (B  (None, 1, 1, 2048)           8192      ['conv2d_246[0][0]']
#  atchNormalization)
#
#  activation_301 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_246[0][0
#  )                                                                  ]']
#
#  conv2d_247 (Conv2D)         (None, 1, 1, 2048)           3775078   ['activation_301[0][0]']
#                                                           4
#
#  batch_normalization_247 (B  (None, 1, 1, 2048)           8192      ['conv2d_247[0][0]']
#  atchNormalization)
#
#  activation_302 (Activation  (None, 1, 1, 2048)           0         ['batch_normalization_247[0][0
#  )                                                                  ]']
#
#  add_71 (Add)                (None, 1, 1, 2048)           0         ['activation_299[0][0]',
#                                                                      'activation_302[0][0]']
#
#  activation_303 (Activation  (None, 1, 1, 2048)           0         ['add_71[0][0]']
#  )
#
#  global_average_pooling2d_3  (None, 2048)                 0         ['activation_303[0][0]']
#   (GlobalAveragePooling2D)
#
#  dropout_3 (Dropout)         (None, 2048)                 0         ['global_average_pooling2d_3[0
#                                                                     ][0]']
#
#  dense_3 (Dense)             (None, 10)                   20490     ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 530625034 (1.98 GB)
# Trainable params: 530521226 (1.98 GB)
# Non-trainable params: 103808 (405.50 KB)
# __________________________________________________________________________________________________

# %%
model.evaluate(x_test,y_test)
# Out:
# 313/313 [==============================] - 42s 133ms/step - loss: 0.0493 - accuracy: 0.9830
# [0.049311671406030655, 0.9829999804496765]

# %% [markdown]
# Accuracy--> 96% Train 98% Test
